# %% [markdown]
# Evaluation of script

# %%
# Core PyTorch
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

# Your model (assuming you saved CNNModel in data_processing.py)
from data_processing.ipynb import CNNModel

# Visualization & metrics
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 8
#       5 from torchvision import datasets, transforms
#       7 # Your model (assuming you saved CNNModel in data_processing.py)
# ----> 8 from data_processing.ipynb import CNNModel
#      10 # Visualization & metrics
#      11 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'data_processing'
