# %% [markdown]
# ### This file is for the implementation and training of YOLO

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.203  Python-3.13.2 torch-2.7.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
# Setup complete  (12 CPUs, 15.7 GB RAM, 366.6/474.7 GB disk)

# %% [markdown]
# Train the YOLOv8

# %%
import os
os.chdir("../models")

# %%
# %pwd
# Out:
# 'c:\\Users\\rahul\\OneDrive\\Desktop\\Rahul\\Study\\Projects\\traffic-sign-recognition\\models'

# %%
file_path = r"C:\Users\rahul\OneDrive\Desktop\Rahul\Study\Projects\traffic-sign-recognition\data\archive_YOLO\data.yaml"
# !yolo task=detect mode=train model=yolov8n.pt data="{file_path}" epochs=100 imgsz=640 batch=16
# Out:
# Ultralytics 8.3.203  Python-3.13.2 torch-2.7.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
# ...

# %% [markdown]
# Test of model using videos

# %%
# %pwd
os.chdir("../video")
print(os.getcwd())
# Out:
# c:\Users\rahul\OneDrive\Desktop\Rahul\Study\Projects\traffic-sign-recognition\video

# %%
weights_path = r"C:\Users\rahul\OneDrive\Desktop\Rahul\Study\Projects\traffic-sign-recognition\models\runs\detect\train17\weights"
video_path = r"C:\Users\rahul\OneDrive\Desktop\Rahul\Study\Projects\traffic-sign-recognition\video"
# !yolo task=detect mode=predict model={weights_path}/best.pt source={video_path}/traffic-sign-test.mp4 show=True conf=0.25 save=True
# Out:
# Ultralytics 8.3.203  Python-3.13.2 torch-2.7.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
# Model summary (fused): 72 layers, 3,014,033 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (frame 1/56) C:\Users\rahul\OneDrive\Desktop\Rahul\Study\Projects\traffic-sign-recognition\video\traffic-sign-test.mp4: 384x640 1 speed limit 80, 1 no overtaking (trucks), 46.8ms
# video 1/1 (frame 2/56) C:\Users\rahul\OneDrive\Desktop\Rahul\Study\Projects\traffic-sign-recognition\video\traffic-sign-test.mp4: 384x640 1 speed limit 80, 1 no overtaking (trucks), 5.8ms
# video 1/1 (frame 3/56) C:\Users\rahul\OneDrive\Desktop\Rahul\Study\Projects\traffic-sign-recognition\video\traffic-sign-test.mp4: 384x640 1 speed limit 80, 1 no overtaking (trucks), 8.7ms
# video 1/1 (frame 4/56) C:\Users\rahul\OneDrive\Desktop\Rahul\Study\Projects\traffic-sign-recognition\video\traffic-sign-test.mp4: 384x640 1 speed limit 80, 1 no overtaking (trucks), 7.5ms
# ...

# %%
test_image_path = r"C:\Users\rahul\OneDrive\Desktop\Rahul\Study\Projects\traffic-sign-recognition\data\archive_YOLO\TestIJCNN2013\TestIJCNN2013Download\Test_data\Images"
# !yolo task=detect mode=predict model={weights_path}/best.pt source={test_image_path} show=False conf=0.25 save=True
# Out:
# Ultralytics 8.3.203  Python-3.13.2 torch-2.7.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
# Model summary (fused): 72 layers, 3,014,033 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/300 C:\Users\rahul\OneDrive\Desktop\Rahul\Study\Projects\traffic-sign-recognition\data\archive_YOLO\TestIJCNN2013\TestIJCNN2013Download\Test_data\Images\00000.jpg: 384x640 (no detections), 56.1ms
# image 2/300 C:\Users\rahul\OneDrive\Desktop\Rahul\Study\Projects\traffic-sign-recognition\data\archive_YOLO\TestIJCNN2013\TestIJCNN2013Download\Test_data\Images\00001.jpg: 384x640 1 speed limit 70, 6.4ms
# image 3/300 C:\Users\rahul\OneDrive\Desktop\Rahul\Study\Projects\traffic-sign-recognition\data\archive_YOLO\TestIJCNN2013\TestIJCNN2013Download\Test_data\Images\00002.jpg: 384x640 1 speed limit 80, 1 no overtaking (trucks), 5.9ms
# ...
